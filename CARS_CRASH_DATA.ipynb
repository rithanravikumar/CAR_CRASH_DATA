# %% [markdown]
# <a href="https://colab.research.google.com/github/rithanravikumar/CAR_CRASH_DATA/blob/main/CARS_CRASH_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Crash_Reporting_-_Drivers_Data.csv")

# %%
df.head
df
# Out:
#       Report Number Local Case Number                Agency Name  \
# 0        DM8479000T         210020119  Takoma Park Police Depart
# 1       MCP2970000R          15045937                 MONTGOMERY
# 2       MCP20160036         180040948   Montgomery County Police
# 3        EJ7879003C         230048975  Gaithersburg Police Depar
# 4       MCP2967004Y         230070277   Montgomery County Police
# ...             ...               ...                        ...
# 15791   MCP2995003W         180062718   Montgomery County Police
# 15792   MCP27390034         200006250   Montgomery County Police
# 15793   MCP3197001D         200011171   Montgomery County Police
# 15794   MCP3212002P         210023388   Montgomery County Police
# 15795   MCP3168004H         220035557   Montgomery County Police
#
#             ACRS Report Type         Crash Date/Time        Route Type  \
# 0      Property Damage Crash  05/27/2021 07:40:00 PM               NaN
# ...

# %%
df.columns
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date/Time', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Off-Road Description', 'Municipality', 'Related Non-Motorist',
#        'Collision Type', 'Weather', 'Surface Condition', 'Light',
#        'Traffic Control', 'Driver Substance Abuse',
#        'Non-Motorist Substance Abuse', 'Person ID', 'Driver At Fault',
#        'Injury Severity', 'Circumstance', 'Driver Distracted By',
#        'Drivers License State', 'Vehicle ID', 'Vehicle Damage Extent',
#        'Vehicle First Impact Location', 'Vehicle Body Type',
#        'Vehicle Movement', 'Vehicle Going Dir', 'Speed Limit',
#        'Driverless Vehicle', 'Parked Vehicle', 'Vehicle Year', 'Vehicle Make',
#        'Vehicle Model', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df.shape
# Out:
# (15796, 39)

# %%
df['Route Type'].value_counts()
# Out:
# Route Type
# Maryland (State)        6806
# County                  5130
# Municipality             825
# US (State)               741
# Interstate (State)       252
# Other Public Roadway      99
# Ramp                      72
# Government                38
# Service Road               4
# Unknown                    1
# Name: count, dtype: int64

# %%
df.groupby('Weather')['Traffic Control'].value_counts()
# Out:
# Weather       Traffic Control
# BLOWING SNOW  NO CONTROLS                   2
#               TRAFFIC SIGNAL                2
# CLEAR         NO CONTROLS                4514
#               TRAFFIC SIGNAL             3779
#               STOP SIGN                   805
#               FLASHING TRAFFIC SIGNAL     125
#               OTHER                       101
#               YIELD SIGN                   93
#               PERSON                       18
#               UNKNOWN                      17
#               WARNING SIGN                  6
#               RAILWAY CROSSING DEVICE       2
#               SCHOOL ZONE SIGN DEVICE       2
# CLOUDY        NO CONTROLS                 626
#               TRAFFIC SIGNAL              430
#               STOP SIGN                   127
#               OTHER                        24
#               FLASHING TRAFFIC SIGNAL      14
#               YIELD SIGN                   12
#               PERSON                        3
# ...
